# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2)
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical 
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import layers, models
import tensorflow as tf
import pickle
import os
import itertools
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from keras.models import load_model
import time
from tqdm import tqdm  
from sklearn.model_selection import StratifiedShuffleSplit
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(f"{len(gpus)} Physical GPUs, {len(logical_gpus)} Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
        os.environ['CUDA_VISIBLE_DEVICES'] = ''
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
def load_preprocessed_data(filename):
    with open(filename, 'rb') as f:
        X_ela, X_srm, Y, log = pickle.load(f)
    return np.array(X_ela), np.array(X_srm), np.array(Y), log

# %%
X_ela, X_srm, Y, log = load_preprocessed_data('CASIAV2DATA.pkl') #CASIA V2 DATASET LOADED YOU CAN LOAD THE DATASET YOU WANT TO USE

X_ela = X_ela.reshape(-1, 128, 128, 3)
X_srm = X_srm.reshape(-1, 128, 128, 3)

# One-hot encode the labels
Y = to_categorical(Y, 2)

# Stratified split to ensure same class ratio in train and validation sets
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=5)

for train_index, val_index in sss.split(X_ela, np.argmax(Y, axis=1)):
    X_ela_train, X_ela_val = X_ela[train_index], X_ela[val_index]
    X_srm_train, X_srm_val = X_srm[train_index], X_srm[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]

# Print the number of samples
print(f'Training samples: {len(X_ela_train)}, Validation samples: {len(X_ela_val)}')

# Checking the distribution of classes in the training and validation sets
print('Class distribution in training set:', np.bincount(np.argmax(Y_train, axis=1)))
print('Class distribution in validation set:', np.bincount(np.argmax(Y_val, axis=1)))
# Out:
# Training samples: 8476, Validation samples: 942
# Class distribution in training set: [1858 6618]
# Class distribution in validation set: [206 736]

# %%
def build_model():
    # ELA Branch
    input_ela = layers.Input(shape=(128,128,3), name='ELA_Input')
    x_ela = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_ela)
    x_ela = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x_ela)
    x_ela = layers.MaxPooling2D((2, 2))(x_ela)

    # SRM Branch
    input_srm = layers.Input(shape=(128,128,3), name='SRM_Input')
    x_srm = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_srm)
    x_srm = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x_srm)
    x_srm = layers.MaxPooling2D((2, 2))(x_srm)

    # Concatenate the outputs of both branches
    combined = layers.Concatenate()([x_ela, x_srm])
    combined = layers.Dropout(0.25)(combined)  
    combined = layers.Flatten()(combined)

    # Fully connected layer
    fc = layers.Dense(256, activation='relu')(combined)
    fc = layers.Dropout(0.5)(fc) 

    output = layers.Dense(2, activation='softmax')(fc)

    # Create the model
    model = models.Model(inputs=[input_ela, input_srm], outputs=output)
    return model

model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ELA_Input (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  SRM_Input (InputLayer)         [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['ELA_Input[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  896         ['SRM_Input[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 64)   0           ['concatenate[0][0]']
#
#  flatten (Flatten)              (None, 262144)       0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 256)          67109120    ['flatten[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            514         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 67,129,922
# Trainable params: 67,129,922
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 200
batch_size = 16

optimizer = optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-08,
    decay=0.0001
)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor = 'val_accuracy',
                              min_delta = 0,
                              patience = 7,
                              verbose = 1,
                              mode = 'auto')

# %%
no_au = 7354
no_tp = 2064
total_images = no_au + no_tp

weight_for_au = (1 / no_au) * (total_images / 2.0)
weight_for_tp= (1 / no_tp) * (total_images / 2.0)
class_weights = {0: weight_for_tp, 1: weight_for_au}

# %%
checkpoint_filepath = 'CasiaModel.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,   
    monitor='val_accuracy',         
    save_best_only=True,            # Save only the best weights
    mode='max',                     
    verbose=1                      
)

# %%
hist = model.fit([X_ela_train, X_srm_train],
                    Y_train,
                    batch_size=batch_size,
                    class_weight=class_weights,
                    epochs=epochs,
                    validation_data=([X_ela_val, X_srm_val], Y_val),
                    callbacks=[early_stopping, checkpoint_callback])
    #early stopping implemented to prevent overfitting
# Out:
# Epoch 1/200
# 530/530 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.8259
# Epoch 1: val_accuracy improved from -inf to 0.88110, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 61s 108ms/step - loss: 0.5214 - accuracy: 0.8259 - val_loss: 0.3013 - val_accuracy: 0.8811
# Epoch 2/200
# 530/530 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8640
# Epoch 2: val_accuracy did not improve from 0.88110
# 530/530 [==============================] - 54s 101ms/step - loss: 0.3252 - accuracy: 0.8640 - val_loss: 0.3203 - val_accuracy: 0.8631
# Epoch 3/200
# 530/530 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.8889
# Epoch 3: val_accuracy did not improve from 0.88110
# 530/530 [==============================] - 55s 103ms/step - loss: 0.2621 - accuracy: 0.8889 - val_loss: 0.3459 - val_accuracy: 0.8567
# Epoch 4/200
# 530/530 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9172
# Epoch 4: val_accuracy improved from 0.88110 to 0.91295, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 69s 130ms/step - loss: 0.1921 - accuracy: 0.9172 - val_loss: 0.2207 - val_accuracy: 0.9130
# Epoch 5/200
# 530/530 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9450
# Epoch 5: val_accuracy improved from 0.91295 to 0.91932, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 68s 127ms/step - loss: 0.1377 - accuracy: 0.9450 - val_loss: 0.2173 - val_accuracy: 0.9193
# Epoch 6/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9631
# Epoch 6: val_accuracy improved from 0.91932 to 0.92569, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 69s 129ms/step - loss: 0.0949 - accuracy: 0.9631 - val_loss: 0.2116 - val_accuracy: 0.9257
# Epoch 7/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9746
# Epoch 7: val_accuracy improved from 0.92569 to 0.93418, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 73s 137ms/step - loss: 0.0741 - accuracy: 0.9746 - val_loss: 0.1971 - val_accuracy: 0.9342
# Epoch 8/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9786
# Epoch 8: val_accuracy did not improve from 0.93418
# 530/530 [==============================] - 55s 104ms/step - loss: 0.0631 - accuracy: 0.9786 - val_loss: 0.2503 - val_accuracy: 0.9278
# Epoch 9/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9821
# Epoch 9: val_accuracy did not improve from 0.93418
# 530/530 [==============================] - 55s 103ms/step - loss: 0.0557 - accuracy: 0.9821 - val_loss: 0.2386 - val_accuracy: 0.9236
# Epoch 10/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9857
# Epoch 10: val_accuracy improved from 0.93418 to 0.93949, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 70s 132ms/step - loss: 0.0455 - accuracy: 0.9857 - val_loss: 0.2176 - val_accuracy: 0.9395
# Epoch 11/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9878
# Epoch 11: val_accuracy improved from 0.93949 to 0.94374, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 70s 131ms/step - loss: 0.0372 - accuracy: 0.9878 - val_loss: 0.2151 - val_accuracy: 0.9437
# Epoch 12/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9887
# Epoch 12: val_accuracy improved from 0.94374 to 0.95117, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 71s 133ms/step - loss: 0.0324 - accuracy: 0.9887 - val_loss: 0.2258 - val_accuracy: 0.9512
# Epoch 13/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9901
# Epoch 13: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 57s 107ms/step - loss: 0.0297 - accuracy: 0.9901 - val_loss: 0.2331 - val_accuracy: 0.9448
# Epoch 14/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9912
# Epoch 14: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 56s 106ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.2544 - val_accuracy: 0.9374
# Epoch 15/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9904
# Epoch 15: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 58s 110ms/step - loss: 0.0252 - accuracy: 0.9904 - val_loss: 0.2928 - val_accuracy: 0.9299
# Epoch 16/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9916
# Epoch 16: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 59s 111ms/step - loss: 0.0287 - accuracy: 0.9916 - val_loss: 0.2899 - val_accuracy: 0.9427
# Epoch 17/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9927
# Epoch 17: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 57s 107ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.2274 - val_accuracy: 0.9448
# Epoch 18/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9952
# Epoch 18: val_accuracy did not improve from 0.95117
# 530/530 [==============================] - 58s 109ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.2938 - val_accuracy: 0.9512
# Epoch 19/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9946
# Epoch 19: val_accuracy improved from 0.95117 to 0.95329, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 71s 134ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.2470 - val_accuracy: 0.9533
# Epoch 20/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9946
# Epoch 20: val_accuracy improved from 0.95329 to 0.95435, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 71s 133ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.3194 - val_accuracy: 0.9544
# Epoch 21/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9935
# Epoch 21: val_accuracy improved from 0.95435 to 0.95860, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 71s 134ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.2590 - val_accuracy: 0.9586
# Epoch 22/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9961
# Epoch 22: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 57s 106ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.2725 - val_accuracy: 0.9565
# Epoch 23/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9965
# Epoch 23: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 59s 110ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.4212 - val_accuracy: 0.9331
# Epoch 24/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9963
# Epoch 24: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 57s 108ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.3114 - val_accuracy: 0.9522
# Epoch 25/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9966
# Epoch 25: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 56s 106ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.3664 - val_accuracy: 0.9384
# Epoch 26/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9928
# Epoch 26: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 56s 106ms/step - loss: 0.0267 - accuracy: 0.9928 - val_loss: 0.2308 - val_accuracy: 0.9554
# Epoch 27/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9952
# Epoch 27: val_accuracy did not improve from 0.95860
# 530/530 [==============================] - 56s 106ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.3301 - val_accuracy: 0.9490
# Epoch 28/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9961
# Epoch 28: val_accuracy improved from 0.95860 to 0.95966, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 72s 136ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.2900 - val_accuracy: 0.9597
# Epoch 29/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9974
# Epoch 29: val_accuracy improved from 0.95966 to 0.96072, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 70s 133ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.3585 - val_accuracy: 0.9607
# Epoch 30/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9971
# Epoch 30: val_accuracy improved from 0.96072 to 0.96178, saving model to finalmodelcasiatest5.h5
# 530/530 [==============================] - 69s 130ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.2959 - val_accuracy: 0.9618
# Epoch 31/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976
# Epoch 31: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 56s 105ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.3432 - val_accuracy: 0.9586
# Epoch 32/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9967
# Epoch 32: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 56s 105ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.3032 - val_accuracy: 0.9512
# Epoch 33/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9972
# Epoch 33: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 56s 106ms/step - loss: 0.0064 - accuracy: 0.9972 - val_loss: 0.3406 - val_accuracy: 0.9533
# Epoch 34/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9971
# Epoch 34: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 58s 109ms/step - loss: 0.0065 - accuracy: 0.9971 - val_loss: 0.3370 - val_accuracy: 0.9501
# Epoch 35/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9967
# Epoch 35: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 64s 120ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.3779 - val_accuracy: 0.9544
# Epoch 36/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9978
# Epoch 36: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 63s 120ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.3755 - val_accuracy: 0.9533
# Epoch 37/200
# 530/530 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9981
# Epoch 37: val_accuracy did not improve from 0.96178
# 530/530 [==============================] - 63s 120ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.4225 - val_accuracy: 0.9544
# Epoch 37: early stopping

# %%
model = load_model('CasiaModel.h5')

# %%
history=hist.history
history_dict = hist.history
with open('Casiahistory.pkl', 'wb') as file_pi:
    pickle.dump(history_dict, file_pi)

# %%
predictions = model.predict([X_ela_val, X_srm_val])
y_pred = np.argmax(predictions, axis=1)
y_true = np.argmax(Y_val, axis=1)
def generate_metrics(y_true, y_pred):
    print("Accuracy = " , accuracy_score(y_true, y_pred))
    print("Precision = " ,precision_score(y_true, y_pred))
    print("Recall = " ,recall_score(y_true, y_pred))
    print("F1 Score = " ,f1_score(y_true, y_pred))
    pass# Make predictions

generate_metrics(y_true, y_pred)
# Out:
# 30/30 [==============================] - 3s 71ms/step
# Accuracy =  0.9617834394904459
# Precision =  0.9691689008042895
# Recall =  0.9823369565217391
# F1 Score =  0.9757085020242915

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    cm_flipped = cm[::-1, ::-1]

    plt.imshow(cm_flipped, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes[::-1], rotation=45)
    plt.yticks(tick_marks, classes[::-1])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm_flipped.shape[0]), range(cm_flipped.shape[1])):
        plt.text(j, i, cm_flipped[i, j],
                 horizontalalignment="center",
                 color="white" if cm_flipped[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Predicted label')
    plt.xlabel('Actual label')

Y_pred = model.predict([X_ela_val, X_srm_val])
Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
class_names = ['fake','real']  
plot_confusion_matrix(confusion_mtx, classes=class_names, title='Confusion Matrix, Image Forgery Detection')
# Out:
# 30/30 [==============================] - 2s 74ms/step

# %%
fig, ax = plt.subplots(2, 1)
#code for visulating training and validation loss and accuracy history
ax[0].plot(hist.history['loss'], color='b', label="Training loss")
ax[0].plot(hist.history['val_loss'], color='r', label="Validation loss")
ax[0].set_title('Training and Validation Loss')
ax[0].set_xlabel('Epoch')  
ax[0].set_ylabel('Loss')  
ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(hist.history['val_accuracy'], color='r', label="Validation accuracy")
ax[1].set_title('Training and Validation Accuracy')
ax[1].set_xlabel('Epoch')  
ax[1].set_ylabel('Accuracy')  
ax[1].legend(loc='best', shadow=True)
plt.tight_layout()  
plt.show()
